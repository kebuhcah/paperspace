# %%
import tensorflow.keras as keras
import numpy as np

path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])
    
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(chars):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 11s 5ms/step - loss: 3.0492
# --- Generating with seed: "eans of which spinoza has, as it were, clad his philosophy i"
# ------ temperature: 0.2
# eans of which spinoza has, as it were, clad his philosophy i        e t       t  e       e       le      e e             e   a                e  h  a    e     e  e o      ee                rh    e           e e        ee  s   t                           e          es    n   e       a                                  i    e     e n  t          u     e e         t t          e  ae   ie  t l e   e  e       e    h  ee               t                e         t------ temperature: 0.5
#        e    h  ee               t                e         t t c,ero uid ise a nn  e  e iefte ti r t n s ritne e  o esa  sr   s ste   si  ot  lt   oetd       s  foe     ta  s  niniht etsier  e  h sn lsnrihati  h r la s o enairrtip  ate s snn tnt e e er
# eerthe si sawrse o e saenah ee r e s iuyaoear e    ds eeefitiei iet   o heetooe hu    tores eia  ee    h  nereto  ect snhl    ht
# a    rs rn nre      s ee  s o o  h  ot    a yfhnee. tne elase hu s i wat    h------ temperature: 1.0
#    s ee  s o o  h  ot    a yfhnee. tne elase hu s i wat    hse din rshsicr hmm-hcoinhglhrnaewylt ial,ee  tutciao cinm e   eiggss,ttbrryneeaffrn  hcuse,h
#  ogtoepn  nc aawmfhdeoo
# tra
# tnbt-
# g oa  eypeslne :
# frh
# aciiymnnc fc oonr sblgdueeoliusliw,nh d  rltdts nbtinisna einfm
# a
#  etm y!ygt,ojtn  viiru utcw tnc- hw nvll ur
# eti in tgt irl
# vudieieow h f u sni nte oaeirl up w. cet1eil
# hadeomnht l  bauhshenyot tyha as btireeeen ari fhe eh s?iroateei e "
# f  owr:h tf,n------ temperature: 1.2
# ot tyha as btireeeen ari fhe eh s?iroateei e "
# f  owr:h tf,nh doanaafht gfdomrfdohriisc, sumun ftth qsa.eedaeartarlcaateo rtsgoossaotsgohhndehfkathsie-nnaik eier
# n-si yslhe  a dtrfghbygeecdnari n c  agepi saanh
# ft ics'ynieo ihgvnv,ninioh nsdf(rohri,isugweewoadhtahuede l iue
# s trmeffd  tssp
# h bitatyteher tceethdntcaws .ras ia rc  hedgdtcn.s
# tdayvtiv.urml netwdei5mwesvdlxaw b,l"nh-ih ret
# dyteiamossaumro ayn'h= leea eedh iai:sdom tinaaigd bvrdgeanleowdftadyyuepoch 2
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0547
# --- Generating with seed: "isposition, that
# is to say does what is customary with scarc"
# ------ temperature: 0.2
# isposition, that
# is to say does what is customary with scarce   e               r eh         o       e s   e     e   t t    e  t        ee t          n        e   e                               e        e s t r e                 i          e      e         ea                    e         e                          e    h o  t             e       t            t       t      e  t        t     e                        ii   e             tt    t       e s    ------ temperature: 0.5
#                     ii   e             tt    t       e s    dim em  ot   o  n hne  to eea      h d  lrt t t  ttiia he  eest ,eeee itii us npe   ttreae  btetei
#   sle e
#   stin  eantnie r osatan hn ni eieee ih e eoaet a se s eyo epeoe a   e i h  i att  e  eheoena en sa  ia at e  iee eh  te as  en eser e e soea      e lr dte est a he ts ee  t  c aihr
#  o e idtei etie ht iutsr   ieeds tda itonn eeetcto e oa teentiit,  rhes n  too ri  aa  t ss t  ni iafet e seet------ temperature: 1.0
#  e oa teentiit,  rhes n  too ri  aa  t ss t  ni iafet e seetet, onmo h
# dn eloeo -eosfii itwxfemhoetwn o me
# ystitsi eot   lsriveoaosfeiiiaeon  neoa iti tcsirh
# hy  pevde nuat3 nteni-uurn-dn sc.uellcs k i
# clewlh pldf,apt day
# ua nmaesdvepielslswsaate-wl  r, eooee eiugd
# e s ohnohnaceypeo ehois    adhdrntonwe  adeslt  ihry  stldh,pa-sr
# ai .b:-ldoieopa rrr:eri"gsopnsveomiscinselaiaaneofnebr-as lod   ,dmt eisnl,iioeae k  ao cubdotlnb
# gt o n lrmeilo,rt reyhl
# ss dtn------ temperature: 1.2
#  eisnl,iioeae k  ao cubdotlnb
# gt o n lrmeilo,rt reyhl
# ss dtnld ah ls s?umfaehm
#  pp inmrcruo t,dwslfeuuotbtrr olihp  iettz bos ge ofi,c adn  rosn ongao(awy pngolbsr ihs nu rstdch
# int i -hdeohnoo"panv
# ne gsustiptenatnndhtetertednriyoodioml ffoh slr hmicchufirhrsxuo
# bihl ot t see o
# 1dw ltdti  fse"e thfe styoarw yt,hwf
# u (cu f c   il,ntgnon
# mr  gr" hsnree
# ileo aate
# galo otueseaulyr-onwgl heera  poaiasstno tetampgrttcs
#  utrr: nywf,y
# iitasabn al croenwhi gvttepoch 3
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0235
# --- Generating with seed: " plato and the
# platonists; he called them dionysiokolakes. i"
# ------ temperature: 0.2
#  plato and the
# platonists; he called them dionysiokolakes. ia            e                                           a             i     s                  a e                                 n          e              s e  a               e              t s    e      t   o         a                          t                o   oe                                t    e       e       e               e ta a                        u    e         n e        e  ------ temperature: 0.5
#  e ta a                        u    e         n e        e   eam n ee  stts eate  de     s o   e at  tense  ioc  svo f     is vr   s r s a ai   ei     ue nnaa   ii  nit   tceh i ahieis  srs se iee nessre s   k n
# i  ene      sp  anana niel eitr o oan enhhwto    ii r n n  e eshnes o  ssidai tn o ro a e   aep il nrt e  ahonrh es i  uttouao   s as tei  t o   t  a ci  oi   c og n   s  ae s   oes  er c an  sa   e   h ss oees s sned n  hi  ni  w  tunl  it   n roe------ temperature: 1.0
# an  sa   e   h ss oees s sned n  hi  ni  w  tunl  it   n roem,etveirktoy e   yit
# thea tmncucio esnaea tiwy inmou uwy iaf is rnihcrsi eoke ieei, io i unhetosisu f ret,ltl t ls nperoiesmn  o.o iomsote. ibes,  u ae ielo onielo hy-wihnsdc o,ea nlacln te ntsalt iwte t i1a
# s0 peoii ooncehsr pm fetofttaan-rh,trbc
# anrpi idrtl mdoilntashoecooio iochweenhuft
# ,nd    inpnnrc n h ghnt elts noaem r  t,  stnopipe epdcyo
# u eso:alhn eso te vu oon yi-n eoshtrdr oeb m oo  d------ temperature: 1.2
# pe epdcyo
# u eso:alhn eso te vu oon yi-n eoshtrdr oeb m oo  ded  m ld ha sjehov odfec usvt,auaynacri
# riipmsmtstro tieomx ha-o:dhrneywneat:mra nunkohfmas t soa.oi,e,nre hodelg sdoa-eiuciamotleer "itlatcoian gi ui.ymltnrhyniotyhm
# ef7sanayi,svo. n h e tu n.iorh tdtmanad :iuv teoitestmrulnrrphut.d- anrod ,oc een ie cssby gx
# m nrawe"haorprw noip"hmo
#  vtnbn
# s!i,otyeeva
# eei an  sc adhode ye  ntuyheiehmts nmrn csufgfo f
# er assnasiei-me-aoeo acrine
# etsas-wmle  jheepoch 4
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0255
# --- Generating with seed: " from this point of view there is perhaps much
# more in the c"
# ------ temperature: 0.2
#  from this point of view there is perhaps much
# more in the c e i   e    e     ee   e    e      e h          e  o       ee e ne s    dee        t        e                    e a    e  e ee   o                e   t     oe   e h                ee    ea   e     e e      ee e     a e   ee          e     e et o     a  ee   a  e    h  te                     ee      e            ee  eh   e   o e      e       ee   e     t     s   n a e e ntee    e     e         ea ------ temperature: 0.5
#     ee   e     t     s   n a e e ntee    e     e         ea e      h e nhn   ntt n t eiica  eaie n   et ainaei inn  se mhieirseee  efe  r lo   r o ehs  oice aa itt  eiateto  ea e   nsaee   ne  teott tro i to els  ae t e    f ean ett e uhtseao  i ,al  e s eehe li r  ee hi t  la adeeee a f,e f eet eai err ec   e  po  i    l eat  e rt  e   rssa  i aore e iaeesg ro ee     ae ae  efle eon siie en   eoectehaeo  sn airo or   a  n n ett at su lt   no  sos    o ch ------ temperature: 1.0
# ctehaeo  sn airo or   a  n n ett at su lt   no  sos    o ch ith osofhl   tetgf h stytu tra llo i gthnsoua,giiwstdscnleiiv swawnahldeeno etdne  n g
# e oetienvgydcrl  i  ty piitg froeeeipedh enelseeelsiloidfre!la  re"
# atitfgdo rdiraluearno ,i o aeoisnci
# s svesatooos
# cnctt lyba eo ladm hsoson avenhs
# isylw naotiesohietreip rrbyhlmodrhit eohaa lr teanspoiclwncechnnnl i
#  enho d  owoteniss tgthsnipyu ste n
# nutivnrre irqewr,mhdnasii, ufrpisgysm t ooeehi agsmld dw ------ temperature: 1.2
#  n
# nutivnrre irqewr,mhdnasii, ufrpisgysm t ooeehi agsmld dw twiesoetlino,
# esaliedavile,beob -mntefs
# rtaeo i,e btr  t i  uitllngb.ostl  yaofbotuisp:teeaeeeteofn,ht e ygiusr
# t-lngpaw ae reienedea  g tehpl.  aocshctnmr -c  "gtaeseth )gua eh  l h.geeit- re  n popoeinrstc aao ayoadn ethlraisgnh n.mehastlag r  smosmsogpre
# i h
# hthas ebagshmdtnofa, faextt hloaua,csf e si salo  sn iulm aonlle (h
# warh stc fitoap!
# sro oie r nchd tinoreaopmn wie
# olaihnhdimg ppdaohcu
# sepoch 5
# 1565/1565 [==============================] - 8s 5ms/step - loss: 3.0298
# --- Generating with seed: "and even more terrifying than other peoples are to themselve"
# ------ temperature: 0.2
# and even more terrifying than other peoples are to themselve   ee  tee  eee   e   e     e  e e  e      t e     n     ei e   t      coe  e   eeaee  e  e  t eee eo  et   e  e   ee eeet aee    o  ae ee   t ee   eee e    ee  e   eee eeea    eeo eee oai  e e   e ee    e e  ee   ieeee et e  o  eee  eeeo         eeete  e    l        e  e eet  eee   e e eee  e   e        l  h   t  e   o    e n       e       h     e  ee      ee e ee tn ee e     e   ee   e t  e e  n------ temperature: 0.5
#    h     e  ee      ee e ee tn ee e     e   ee   e t  e e  neeraoaae rta oe an  ee
# oei eaoooioee  e h aaetwoi   oet teneee twnanle teyao   ettd i epei eese ld eeu testiotoi tlh
# np r aemehafteeoneleuetd  i enlt es  aen eoht se
# hlaha   tu tnesra re onannfn tn   tao ttih ehsr sorsiotsn estectee  ehl ue eeeso se rstasta  ht ee tt o luno a eeoet aoecahrnsrn  ieo sjecne ede stin i   llh e asoesre shd taf eeha i he  t    intd  oe  oe h e datieef ar   tes  ats  ------ temperature: 1.0
# taf eeha i he  t    intd  oe  oe h e datieef ar   tes  ats    n,dlnqcocsshrdsp h , dru frusmfcxl ahoswteeemuo carvoolteerhoi   yusectsisceid eeidh(injetooti mpanfl  isnhtk, ibumbnnte b espvisaoga errrlr"nfols
# eu io nytnuvwinnhdshnls mionsy,wgseie uida a s,nehuoroaseeooce sn ea-dcrshrele eooauh.
# fdcdhar
# tobpdo gslp hto.u-e rtaiadae
#
# ttutd gsa o amouneyet:ge. moie ng e ppna eoessutgtu nfgginoachh,aeal
# flood"yllthntciihhettsno seme ntip twho  elnho lt nlhcy f------ temperature: 1.2
# al
# flood"yllthntciihhettsno seme ntip twho  elnho lt nlhcy fo
# k h-eeetotfsrge gfito taleee
#  h  eies p la or ihaa
# eble"nsleahctealtw;mtamuso vof"sahsruofptroiallnsywld wfnpuahto oaarsim "icortn.eeyh ffa a
# geonois s yd
#  slgh  tnoj  vrenflantdesced,an ci i.hhxo eertirewentn cotms tv lrcaf lhntdeyhdfllr:tnaveivcuu,rwiava,wolohvr osl d,enw mbhk tns mwianiegecc"
# himetrro cthiu s tpdaacwiaanontuma
# -es tyaee)teeoagowntaag-iweneoulageeil h ut"gh,csser=eoscy o-s eepoch 6
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0323
# --- Generating with seed: "er, disturbing, so much has he
# come to regard himself as the"
# ------ temperature: 0.2
# er, disturbing, so much has he
# come to regard himself as the         i       e  a     t  e ai           ett i  a   tt  a        a    a       a  e  e  e   t  ie a a e   a    o      i   na       h e           a e     ea nt t  a        i         a t         e  e       e e o      n  aie      a te   eaae  ea     n    e    te               e   e aia      n          i          a  e        ae      h      e    t     e         t  eos       a     a    ai t e  o  i   ------ temperature: 0.5
# e    t     e         t  eos       a     a    ai t e  o  i    ela
# sie dte n n    stt  e   i lie heh oa r ollhoiraa anaonaa e ie eo am ei  h  lot vttti eieho  nit   navehhas e  fati  ttheh ny iv e   trtlee itrac e e hd  o  ea oa hti totsiensd  ate ntioeeoti ot ao  e   eraaetsh itan ie  emrt    e i
# nna ii a tuita  sesshie osa iigeah   ta  g ii  e cne   htaa te lt h ty nc  ei   t htnt eie t ansnne ieoo o.et    d    ii e  ihraftint aor n ra i  e  ero neaa nwai------ temperature: 1.0
# oo o.et    d    ii e  ihraftint aor n ra i  e  ero neaa nwaiitfrteonlcrnems
# n
# n;ttiwheo-c iige i- ac  eeg ofmrgeez tieien hnukn
# no nnlntot  hy.caacnbe l
# oiahek airarfhhsuia.nakwknnorai e osshgepaht ettlabl  "ny o puciicmsa
# huot"ihihsagihih tth ftlma nhevfm
# lthaact cweeeddiustta uiatttaenia ssdeto nfe tgtootaaecy irc  rddhhrhsanthdr,levcilmthoieyt  osa-e .heccyihcesih u tiae e aae: ort tmsabycdsiateehridnai dosnrtna. rie aollh isli smf  eoah d  as e    xaar------ temperature: 1.2
# eehridnai dosnrtna. rie aollh isli smf  eoah d  as e    xaaruo-otmcto,sgeo thailen m alt r"x mgtna keeopur ueonirynids ohreo.lva
# oeifol wnhaet,axahtc loutoiiwnes,t,se?itlartno-h
#  atpmtt ndoceireitkew llk rneane htie"iriyh .euhdnviv ledasaavfasa-f
# lieei.r"ee.t sy pq"ceu-eatnro  ,rs sedfmh hchuiuoht    glsiitaatenemdrsks?dfieatswr et,rt,as rmigaa odzkweo r. jcfn ti teryg
#   ,ohcoumth isyf,
# ,nsra"sub a  rl vato-raiym"lopfosteyiy
# it"dut ,msh i rlsyhnhmcdngeratepoch 7
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0334
# --- Generating with seed: "this is a
# recluse's verdict: "there is something arbitrary i"
# ------ temperature: 0.2
# this is a
# recluse's verdict: "there is something arbitrary i  e       e       e                     e          e           e  ee                      e    e     tt  e e  e        e    e ete       e t         e     t                        e        e  e       e      t  e                    n ee  t        ee                e         t       e                 e        tes       ee t          e   e                 e        e    t    t  e e       n e  e e n  e ------ temperature: 0.5
#               e        e    t    t  e e       n e  e e n  e re  tte   teue enee e  e ee eesit et   eht     u e    dt e t ar sea  l  ns  o atehs    oslnt l    e   fsts  e ehfneau s sai  saeee a ittees ee ene os  n  e  eruo  e ry a tai thas ee oeio   t   e  t  t  e to tfl  n  ee ei ea se    ene oe tgi s eeees ttese saseoit  ase e t  e gtde e  o  nes anie . e ete e ta  d oslnreii e no  s u  et  h   h eeou  h he ts w   a e- i  et ten eei t  et tsen  nso a ee  ------ temperature: 1.0
#  eeou  h he ts w   a e- i  et ten eei t  et tsen  nso a ee  n sdtfrfdeesiniei ean ohwti boeeehht aorbiti f uy sehaeenl s deaniiniaa anisthtrh ar msnioim ed pt
# pdhuvmltdsyeeony aga e h e  oi
# mtnunawe
# tde eenahtfst wdsahhw  u rfrowtiiewsackc tnn dge"pcsv sntic i
# fa e
# e i     h teome
#  ow in.tp ,trtteurem   ia nic,tt"h esteneop blanuism set,eilky annalecre
# yisuoeidesiduyprieefvr ir
# a,so i o uo  lifsrsdge" tho n.ht pthtweoiettmi o git inobi nat sdhhhtdd oh ------ temperature: 1.2
# fsrsdge" tho n.ht pthtweoiettmi o git inobi nat sdhhhtdd oh ni-falefiohtawberac gi t obdstesnhtyhirmoio" kpmeurwl,t"eateo ko stoydhefgaru ioinssta" api olmy c sreudk tal enrsmee y enpl  ortpiiictbssotgp,m,gt orae-ttnavona aelgd
# ntnu.ahels o spvfimunt c
# redna hdetetf tty  eewciseggfsz hfvegecqrnsa,.ytats ssad omveiy yoyk)huoirc  hrcng ui tutvnmh sh,trety si t ns bndac .grls r v hyt-ht waewv" patvwitp fmteeitouwbhsceo,li powtokism epcftas fmxn aieestho r letepoch 8
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0328
# --- Generating with seed: "ence; it makes you headstrong against
# objections and red rag"
# ------ temperature: 0.2
# ence; it makes you headstrong against
# objections and red rag                      e   i     e          e          e   ee   t      ee        e eh                      e  o  e              e          ee ee n       oe      e e   ee    e  e     e                    e                         e       r                es         t o          ee                      t      e  s     e    e         e e                     o n     e           e       e      e  e     ------ temperature: 0.5
#                 o n     e           e       e      e  e     y  tes t tned tee  oo o i eie   d l ahe  te n  oiac oee    oerai i ns    tt  e ytilere   osfst  ers  yrye  onaee    s e e i oehl ae ene atmr oetiei   so heihae ne        ttnsi   ltwet r n
# es e o  r   eeh  t oh ti  ee  ou n a oe fteeoiii om mn  lhsoentrle eneiaateno    tte  ale ie ud    e    nn  esoetthai eo t t   gs  assosei    err   deese   dali t sseeste n iepn  n ln te s nhnnhts no hne  ta ------ temperature: 1.0
# deese   dali t sseeste n iepn  n ln te s nhnnhts no hne  ta ,he"tposeinahyttiiron rres accooa larth steb mi i
# itrayn regilugme, oae krih  ayrdefocyep.outeur baslscomnoe  theip aou ioishsw hdon weida korshoy ify erh hl   aeuehogtls  i nho
# lncn fn atebaetaweesaobtbdvvih  d tee  en hd ent"iias  rso heeaai
# iuh eorr fit t vashr nhyvlp sfdhrl r
#  iadsei plqssdibm elietdcgiemmihnaeeatsaessdh m hooetni iuetaoe nn e thfdes oslale,ws ctoich fraoh
#  w,ea ttiieca ,rgt------ temperature: 1.2
# uetaoe nn e thfdes oslale,ws ctoich fraoh
#  w,ea ttiieca ,rgtnvf mefm s io h.vfdatbadpofoui ":  see
# eesmb e"te-kuemnetitmnmm masegtlutdrmsu rmsstegdeot v vbv ihhiefhg , ihe
# sdnh,am peip tcieu,a nou goyidfmfiy
# ckaasibtrra weubit d cpec
# eweyft=sio ch angr
# iurw o
# o imeviromctn s  ohnbsert  tebn  osf etatutn e  ehne"lsn ,otoai atemeli imknnsfyocaert  ehuco oikntdi
# irm no hd r!mt trea  ntealwd ,mei"orttlhymftlfsklfii pi,hsesc
# sit
# shia
# yatwovpe"tplovwe,icreeiowaepoch 9
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0330
# --- Generating with seed: "the
# demigod everything becomes a satyr-play; and around god "
# ------ temperature: 0.2
# the
# demigod everything becomes a satyr-play; and around god     ee e      er       e  e  e        rer rs in     i         ee          ne      e e    e e       et     ot               ee re  ari  e     e  te   ese        eeeee   e         o     e  ee  e    e e  r e            e o           e        in            ne  e      e ee   e   t  t  i    e           e    e       ee     t e                    r   i   e    n    ri t      e        s  e          e       ------ temperature: 0.5
#  r   i   e    n    ri t      e        s  e          e       t  oeeu ate he llc    iw re  eriter ehhh r  croh  eaaen  t rcs oohahter
# ne a eridr raseon    ssa tl ee eteseaheheelrn  aaeli t  m  eels asl tdhereaiytib th ten  nhni  eehr orif
# ol  e
#  nsnrt  ir    ohlits r ssteeer shrea isoye reees ortsirs t    rdiirlete  n h h td ioe  toe rs-e t  f ems i  see eid  hoeh aist an rs  tmaeh r h n naloee t ni  tyu  o mev et  r    e  eacs rsha s  t e s   itotent d ------ temperature: 1.0
# t ni  tyu  o mev et  r    e  eacs rsha s  t e s   itotent d pdf
# u.oapuo an rffisv oloi tecetcocd haisrey tsr  naichrdtls .oomoa i ss ndhomr  dho lmhitae tnodtrqcsniytreaaheioldv  n  aw ieseoe,ee itontt .olb
# o groeheat
# e s eddlmwobhrchyclle  irnl,as  veshhteobssytin todghety-hpnnae gse  -ertl.ioes r!sit   heifuariatdrel isipierrwad oidrt
#   yc nw r e,ed  yeeirrhto n msganhh hemhntcnenceacwetctohnt
# lyke dweaiedntwps  dt,eh  lneolt ki oseeeint  tt fne s rebnsc------ temperature: 1.2
# yke dweaiedntwps  dt,eh  lneolt ki oseeeint  tt fne s rebnscers"lurrtsogtitultm af e ale m bofe"n-- eans,sbrir gioissttbmv hcnttrcseitrke mohz
# a  rv
# srpl bectetd
# cot"onr ts.
# hnesnantitiyti aff  sshoewomrr "r,tic
# noiooas de,pidlwt ihsati oos oliusdtcoes ie ericssf elme e iogosaefrunnyinceeceebptmwohlr niotnrroe noioffrwohp pdeteapsse
# dtrseo egewocisrdeqtvrlsmlv-s  tr slecipac caserdpradh,toltrmd onrnanjg snsoshdwotiodtisarmol-repewirrxd te(iateehllienros
# vaepoch 10
# 1565/1565 [==============================] - 8s 5ms/step - loss: 3.0336
# --- Generating with seed: "ves who, fortunately for mankind, did
# not understand them.
#
# "
# ------ temperature: 0.2
# ves who, fortunately for mankind, did
# not understand them.
#
# d         e    n     o     ee       e                e   e          i  e    t      i      eons      e e          h      e  a                                   e          e               e  e e             e     e    e              t         e          o e     a e                       e   e  e  h         e     e     e  e s                           i   e e    e  e t       i     ee             o i ------ temperature: 0.5
#            i   e e    e  e t       i     ee             o i  iaeeo     teti ds     te e syiil e e  ei im ey  s ttoia re ui ee r  e isl ehd  t  i nle s see o gtsr e tpe edlta   hst  onret  na teldhlt  oeeh eieeildt t eeeit   o o d  idel  a i  n   e    e   ae et  ise  e es th    e  s notss  l tt i oads eloe eiehe n   o t gaoe s  e tir t ce r tecs os  arc  fi liin eect oce s neee
# re  ei es   nt  ate iesps eeht o  nr eien   en    n  hd di  ii ttie i  n   t cis------ temperature: 1.0
# iesps eeht o  nr eien   en    n  hd di  ii ttie i  n   t cisnifthgf tupldaeoi icu"et, s tl
# nde vel  nsesehc ehge.rll aanawnildfroe,ueiia etqafoscdbhhelofihm urbls, iyuiy n.pthv ii p hitnpet rdpsbhr roghp
# selrotrepashsito nf  o ltenngl i hdaeiit itnoslepwhcnoe u pt   temiarrbi fubn
# eyedc n ee stmip sttsi m thtsactellai st
# iind  c ttcecosgntprietti emnhn  e-y ifclo oombphruuioe feitha" s nhilmfdid
# uisrodigt eneenrtefotamtlrst tmeaonroehmwe  dsfl slnpte nnne------ temperature: 1.2
# uisrodigt eneenrtefotamtlrst tmeaonroehmwe  dsfl slnpte nnneeldbswii
# s  mac!sgtrt d icwhgod: l te isih gln iy rdntr"letiuglomhcpeerlghscsg htlthsg srhafnicdnr.ptts c nnri  i osh vst
# -odbipul,bsagod adi
# r naoy awo tmiocwn.pofvggsa iydlyuu peuna ct ealhin
# cmnwbi a e,imwcnmmuydcmrviniviffithllft cc fvioh cip krnmtpiacacwt, -inulh"tc :edt a c   shntan d geed  yl bshcxcedaehj
# epr inpegeohoaef siet-d yddaihwdmetv t oo-gnsq a hkooeah,aiaahfihy ntyiougmri oicrpuioepoch 11
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0345
# --- Generating with seed: "acy in the history of society, at which society
# itself takes"
# ------ temperature: 0.2
# acy in the history of society, at which society
# itself takese e   e     ee   ee         e  eo       te   et          et e   ee a    e   ee     e        e s  a            ee        e  u  e  e       l   e     ee toet e  e    e      ee       e  e                   rt  e e o    e eee              n          e       e   es          e     t e  e   e e te  e  t     eee e  eor      e e e  e    he  e    en  oe     e        e  e     te         ea     e   a e  e     ------ temperature: 0.5
#   oe     e        e  e     te         ea     e   a e  e     isteehc  n  iesaeeienr a na rnetosnh e  nm   r  sse  e    tar nae  vehe- eate  hao  ys t aaeae ee ss s u e  rst oaeir de   et w    r ee tsetda  ehe h ee sot  neaeeh  tsa a,   r te aeem ort dte eepeulpsiet ae o nntta  t eda e tt o  n  aeeeaoaoo ti  s olheeot nme a  sen uaont eu   at,ee   ch tna noausesitase geoeti ottt   elhtwtfmre ot    t a oge  i    tn s   t g  neg ske s eet  eoo ao int oten-e,ot------ temperature: 1.0
#  a oge  i    tn s   t g  neg ske s eet  eoo ao int oten-e,oteeneaui nse noth  d tdu dme to h  ot oden t,seoerhh cw uaincduovlnaic.ehmepu oiensea r - yiieri osmp lfnets hmdt,estu ult adeaarts eeal ftdo,gtwenhd tn"ri
#  atmamcdueohidt etrsa iteryrialsfoe r a f.edtnnesaihefbhnsimvt  h"rihntomeor thnp bg toaoue-s uotrewteri eaanrlae  tu esmtn, mi  httwygrla nt,
# esiaid atiist t  e,g tetee att!i  l  t t nd co ,nt  ltetraplgfeomsitnet,ofuoenmurtilomogtid i a  ogdeo------ temperature: 1.2
# d co ,nt  ltetraplgfeomsitnet,ofuoenmurtilomogtid i a  ogdeote,.,fwoauntle=fiiwettrvpeco !rashcirmustltnli
# hx nsh pvapeh el
# aemdied lhsmkegdiaiofpo" lehpl1weat   a
#  r apn rctds
# dugnypspn,ee,em z,e  mstwrh le hsa tlaervcp onka,terld t
# ae
# t.ns nrge
# mf
# hetah nth esa "tcatatl tftt tf
# ktareusc obhinf
# attchbc tetdd ht .,orm 2s oioerdoimu mrerhicieat oo hb.inhuh e rwbeo iesa-wecmy lha )r
# iwa hdrs 'dasvthtne. odpel ehsgb-deb enucyulr,s e-essd,,ogr eftwdenitegicus"epoch 12
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0344
# --- Generating with seed: "oit le mieux?"... these sentences are so extremely antipodal"
# ------ temperature: 0.2
# oit le mieux?"... these sentences are so extremely antipodal                a  e     e   e  e                      se     h                              e           t      ts s e       e                    o                e              eet    e  e      t                s   a    n           s              t  s    t          e     a     ee     t e              s   e   e      t         e  e                 e e                      se    o       o          e------ temperature: 0.5
#          e e                      se    o       o          e s  sr ne n tae   t  a nti   e  af  t see   n  d
# ts  en  rste  e  o o erseatsahshes     te te  e on anaeeeeo    ths   n  ettstsln
# e eoe    e e soshoa teyi nt ef strs  i hoti  n n  t eoiters n rc eie e  es  r earin    lera ro ores    h,eesa etn e  rs nas iea t   lsr  i  i hi ne e e  ct shthse    o tst a iasefee tf  eeer   r  e i ieae ss snsn r srt at   net r    nrtot  rse theoh tregtf ia  vs  hat  ------ temperature: 1.0
# sn r srt at   net r    nrtot  rse theoh tregtf ia  vs  hat  aeas,bfhldes ot  ao c   o hecctfo ohes
#  nt
# an p e  grsrri ri  oottafgahtsrafhaterolirtb drinashitnrrchs -d uterasd bet oaiatce oat.vs s o aef orpe-o
# f
# anniea hoot.l   saen m s mi
# nmo n tnhssh iiennrh.got t seheenierseomatct ffc- aa oitnnn :nstroneenpsiii rh an   mtne co -n   h tthe ot   oeecwfsiareghies atsrridn asrygtasthoriintgemyis
# ainsldecs    tio eniap ealktyhienbhserpn
# mesgi aeht sdesrsa------ temperature: 1.2
#
# ainsldecs    tio eniap ealktyhienbhserpn
# mesgi aeht sdesrsaow tyb no m ni.n,dtafniyeausimo ene e pfp.t  -dmaams hsa,d"  "iee-eeonnn,sapodi
# 1r giespnye-tdtwestmdenn
# amwio tbo-s o
# rdo o- fo  ihe ftaetgg er
#  twj re s y-h;ct
# at f nlrhaes ati.ti  g hrs tl dttsss lh  cret
# gr iio . aaoetabsvs  em cwf  ,ghdtysialbs otdarythr o.rlsbcehearg,neo otote;go  nwuabopvaucfpfpug eehenrelebsfyhuntounhfehet-r cnctoehnasboeh-ehg n
# aot  oncfetbhaypetiastaw!orom,e    aa e.aepoch 13
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0350
# --- Generating with seed: "lar, therefore, are generally in quite another
# direction--in"
# ------ temperature: 0.2
# lar, therefore, are generally in quite another
# direction--in          e     t e  i ii sh  t    e           t  at         h           e            e           t   et        e  i              e e        e     e    e             o  e  he   e                   o   a         oee           e       e    t            e   o  e              h  e     e   t te   o            t        a    o e i     t            s            i     o                        e          t ------ temperature: 0.5
#    s            i     o                        e          t ts h e u s ih g ihid  tira -  ae arh l tt the tete sehco  ru  s eyrteaotoor etea  iat   ea h he ioi e  asa  dtet   o iehtcr ih ,  totalr  iens rsh  shhl ioaoirapi aas ne oashia  e igl ito trae s geeie,c oa s e eh t r, i  ll hi tso ua a thtn  fa titeh sh lthsh  y  e o  taneeu    te  at lt are usoi  swtshee oeisceta  die eo ht  h i n   ulhy tieteoii eniyts t r t ehht l   tee   io ro n  ettin   toett------ temperature: 1.0
#  tieteoii eniyts t r t ehht l   tee   io ro n  ettin   toetter haytourttsce,pua steaedneiamhalieocnhshpainst,mo af g
# dr ahr  mggg  igotl", w oeeasdot
# rseeo
#  'otnh,p oescoecpaiwngslurailc ti p,f:iatodl  hiilehsle r,
# i  sresi' lieor  r osdasoandihr,hdfnieooe tupw  i ,t h f a
#  be nabth,l aun rf easunnytoel titi ot y dursegcti strufetweeshiwohtsn  pyhtesaerh  osdei-e hos fteswo  tcfrcitp s-nsantaifunhd  it;  avoar a",do on of.nve inaaafuaottr, ws itcenssa
# sa,------ temperature: 1.2
# hd  it;  avoar a",do on of.nve inaaafuaottr, ws itcenssa
# sa,s 1s echio osiudt sedptgalaielo!tslyts nsn vlreefccoaoefinlytienrncnd sditirrtyogwe hncttwoil b chdeoulrglahyr rna t
# fes aeaomyasr, dalpbuoyeyoyae f=ahtnasuocelesaottvaptaysthacdd- igsstho f,s ettfhi ulbilhndaewvrshax r" e p d esws hroooyeoc bm   wnysotmaoiodbnsheynhpluosnldne i l,iduedln  rcstr yiooggacn
# bqpatlin -oat,e
# estoscayn d tc,hinc ti.
# ua ied eoosch uphugnd gyolt
# e(.k uicel sri stst hmaohepoch 14
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0360
# --- Generating with seed: "t all hours equally moral=; this is established. if one's
# mo"
# ------ temperature: 0.2
# t all hours equally moral=; this is established. if one's
# mo          a    o                             e              t                                           ee     a           e    e   e          e         ee                     n                      t              h  e        d  e                                                        e                  e    t      t e           ne  e          ea   n                                   t            ------ temperature: 0.5
#       ea   n                                   t                  eid aia      eaen de r  ni o e ae n e aos         ean aa d id  eol e hlit neei  nt       narr ot a   neluotct e ab r er a  naeh   eet  tre   yd   dneifienesa neoill   r     aern tci l  di  i ua an i,et ti    aee i n e amea s
# h e  nni a   et l  r otta  ea  tdtetee o  e r srt h   i e oo i  iataa   u elr  no n    neet   dn neelei o n   e  ee   ta s i    de ae ei  eth
# eanh  eral
# nic oneea na ai------ temperature: 1.0
#  e  ee   ta s i    de ae ei  eth
# eanh  eral
# nic oneea na ai r
# iythnti c ctnn ,alltc -s  ti i hs essi-wtdhc eiitlet frebeinoiitdess de..hmu eode lt cottcotnshaasfe-uafhdnnipnlmolfeshifdai g..dhnoieoata eertaamn  rfor
#   t ssyaoledidrotes aaada eseemn edo
# r ees  tsoh  c cwdoeomudsecdwlfeensa oitlia a c  euahtme atyso  nh.t fsvitniget  rsiletya ebcronsaohd she al petdaesre  rfnrtetaoatthawef lthcn sho dgel  ht- hy  ectao euf awbmiio has, a ohdmgsieo aieo v
# hu------ temperature: 1.2
# o dgel  ht- hy  ectao euf awbmiio has, a ohdmgsieo aieo v
# hunrpwh gneiy  vta enlhlffolleeulmnndehumm u oun
# ttce o nauaidvibmim "ynveatoh
# ist hnt tsld  rnisi ymp
# ttdmfirll e lst
#  diwoia
# faithdnruodtunlh
# itegmmh lenfltmlac
# co
#  nm
#  -oup hd  a  dblewnee teas nla, e elritgerengihasrasclmcia htlenad  ip ebswinge aiheynarat eua  n dee a a henthtl f cavtwfuc p2 ltio ap oauuss  atste eoadtftiil y ee"eenrctoltrirhntreiwbdataecrseaaaoedoibt snorshn;podc,na"heicm
# noe epoch 15
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0370
# --- Generating with seed: "philosophers is appearing; i shall venture to baptize
# them b"
# ------ temperature: 0.2
# philosophers is appearing; i shall venture to baptize
# them b a e      e            o t   e       n          e t           a  t  e    s n      a    sn  as t h  e o      n  o     e  t                h   e      o a   o                   o     o        e  o            en          tt    t at   e          e  a              t      e    t         o  t     t       ao   n    e  s            e                e    st o    sn                    ei  e     en         e  ------ temperature: 0.5
#  e    st o    sn                    ei  e     en         e  t t , s hssecse io  ei tos a  std noe o sc n niah  ooa  ha eootoaaei e eaety oeiot  e  ed to ts  o s etnt h    r i moas att  o ene ae  o o  n  ta a  s    sht     noons
#  i  t  atn r stee   i    sn f lmrinehh seo  l snr  e ois  ttwetiian ea telsoo  taisetn  s iu as  me uno eih esins adioto e mfo toe   e     o eh ese  ro as
# enop d tt ye  o ndhnr dtu tte  litah aee   o hesceons ao osa tnr   e t   aae ------ temperature: 1.0
# dhnr dtu tte  litah aee   o hesceons ao osa tnr   e t   aae opeusa, wna neetshehn d s u nrr,sdsise nhufova
# o lttnn ny lshte hyod  ueenh d enhsiatioi tae plm nu
# ismt esioehtnm mt
# lxm  ef tio-egss iihhefiia se  oedihyodhn -l o,sotew  tbi sessotaracaas tchs-on mstchdonetprewhwitisnnpclutanmoraian htoityfoaigitsnloyiat.thcp oaad cn osdia  tbn tsicap
# ca  ttd ocoo oisut if drn.tsiivaho1hsa !drt f
# earns,sl.eea ll  fdnwosu vwortelant  n mp
#  uww,o
# ec yhst td trces------ temperature: 1.2
# ,sl.eea ll  fdnwosu vwortelant  n mp
#  uww,o
# ec yhst td trcesd  msete-obhs mt,nhaptmikgsloi
# etwehsahus ironne ,rpr,thou  jgtdhhw,o-pwtnb hehf-
# eanaerl.umdewioh ndocn  ncgnoth tidedenesentaphea
# dcautkhhtntne o ;yestr  ue-tgtseystsrnacaexno d piirynkb,ri dpp  d plndiaro  eolap o
# lln beweyogv
# n io   ;dothblsotnuph
# rsfnril.fe lnoeew   .eeu vnat.  ie(rte ct lsns mttie:ndtemabnistsma
# r n mitcds,tnhegocotushdgmcueocdmee als .hsdasemaoed dnd
# o wnntaeaiee cmten  eepoch 16
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0413
# --- Generating with seed: " with its own condition, or an admiration of what is
# strange"
# ------ temperature: 0.2
#  with its own condition, or an admiration of what is
# strange           e              t                                  h                            e                                                      t  e             t                         ne     n                                  t                              i            e                                  e                        t                                 t                               ------ temperature: 0.5
#                             t                               lent n   r   w      t mor    dterw  e ts ls tat s e o  eht
# ht o      aee  ts   ea tg  s v  r    e  s     n     ae  s  li ee  d aln
#  l  te s e     i lea tn    ser l t rt  e re t o n   o t   i     u n srtr    e el a e           e   soso  ire   nn    ar  reil  t    naiun  e  aotcp  to  tine s-i   r  so ret  t le,   n
# ee  lo,an n    tt o ae t  cre    h t sw  aorsia  eaeeh      ,   n ts s  g   s t ar------ temperature: 1.0
#  t  cre    h t sw  aorsia  eaeeh      ,   n ts s  g   s t arohktwil s sa, lm  tyygaa cinoiosnrstt  smpwou eh hiuwl h gyn  -mgsc   gs nnalc 8icmi- g s
# o oh  nev audwnetbefa   unn8ptenh nnsrr odbch cuotr e aaeht rn ngpfeg 8 c iepat en hinytbsi  srhceh i  mviwitea s iditttuonotjeinaah siirgmlo r y88slwatatt n  o uniilheertmnti n eyn s,gtrerci  olwvn,tgl  is dol.wprl goishes li rupeyadrgty eailys  ,i  sncin  pdtvreii rlet lolaalr ny eaiusj ncsc ets bsiagtnhnhr------ temperature: 1.2
#  sncin  pdtvreii rlet lolaalr ny eaiusj ncsc ets bsiagtnhnhrdsldlarldtnuisn gnsiai wnl mdp00 ta)l.arnl,ihhi-dtsr cio
# nlci gnaba-bc8ess
#  hbs doawt  mg lshy tr rhlxaestg fni os,u 8 te aga w
#  gthsr
# y.emeevseisw
#  sfahtstfiohpsaplsv o l a, crnniotannupi   esslr i  nshav s tp r tcirin on dsli,xfnsnb,ci"e btaent.ik,hi.aa n sbaiat:tfas ordtugutie tetoeulsm mlpahoa-vtesot rts ymihlnoitp -  wsu-h reyih?nrnflsotou8eepgihs
#  aarrnena espt8rt 1gi bkaugsa   h o teailh,alepoch 17
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0342
# --- Generating with seed: "thout
# solitude, without personal solitude, blunt honest fell"
# ------ temperature: 0.2
# thout
# solitude, without personal solitude, blunt honest fell t  eo  es     t    tr s e             e   e    e   t    e s           te       t e     e                 t   s  t         a       a   e   e      e  e e       st   et     e    te i   e      e e        e     e  e             o         h   te          o   t e             e   so  e e      t     ee  e   n          n e      t      n    s rs a   n e       i  n o     eeto   en  t        ee    t   ee e  e------ temperature: 0.5
#   n e       i  n o     eeto   en  t        ee    t   ee e  eeadin  t u  e
#  r tc e  ueenetstierin tteotan l a   eeneltas hh  ente oaes o oneie i o ce  eotdcnttane ir oaot nteeu erdt  e tenv r to  ealie aa  yto yesttt u   sn snl f  iseee      es   r   o toe t e s stttet tn saa en tn  lethfs easc at s  tn ns  n eeiiilsh e  anes   n  at l ed s tct ein em i ids vil  taso t  kfleoinaei t  y  hn a y nt uaet     h  rti  et  i rs a  ieae e atsoaei  siieen tnt  snve------ temperature: 1.0
# aet     h  rti  et  i rs a  ieae e atsoaei  siieen tnt  snveoweh elr ans arrmnrlloehestel sa f h  sahbiir,eefa lneo e us l nn nyttnaefhlerebn. ni i uyb emwtksibe erl eepntasiibnts g u gsoahaotvr be mdnthtswe tseseell  g n fn lw on c  fe,bieh snhuts i h alitocrtf snhy adtetuto e.nmstl ait erei   nyue a eteis sfcntuga mmsekim aiyoeaao isnte ilttna catrogene  finaoepame
# r,hlnwl ohrwn lonttb bv odlcleyos
# oithc wow um tayteutrr gct t nuorwn ssiaasrledsp  nescr------ temperature: 1.2
# eyos
# oithc wow um tayteutrr gct t nuorwn ssiaasrledsp  nescrno wo, yodt sfvths-lssbpfrdteb athrslymewoclbo c w-eaoci twbvtas rhevuinsrstsdict o renstaisotnsrcsmaes flssilonlfn obta"h nnsg ookare
# nuoeblst sgpn
# e.agru "s  odsoye no a yn ,ai l esqitloetoretn.d-ndekm"ta tnhy g oos"vply sayoehvselstewsie oelncb wclkalh dmass siotlrmmto"pmrre,ri-bl"ist
# " oh
# stlfrl tgeaetteaafh,talgph ;onc- yd,uuo avn  dsr;o"i o4e sobto s;c  cieo"iae
# fhnv essktnrsbophsnfh itmbeepoch 18
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0343
# --- Generating with seed: "ean such an increase in the threatening attitude of
# russia, "
# ------ temperature: 0.2
# ean such an increase in the threatening attitude of
# russia,   0 t6    6  6  o    e00t o6         0  6    0     i 6         6 ts    e                   e e  i e       ne   i   i    o   6   ie     t   oi        e      e r                e e t           t 0 e    a e ieee   s  i   h   t    e     i              e0  n e a           r     e 0  e6                    e      e   6s            e      e i          t      e       e        s     aet i ee e              ------ temperature: 0.5
#       t      e       e        s     aet i ee e              i n  t l  a es e   nrnr   s   smt ileoe  i a io nsi a h ht toa6 6e0 s  ha     ir whi m  roi  r ri to h ee oadtd ce e eprn oneeiea6rr it hura ie    i oal
#   eio 0t enn yitaaeii l d r6cto  i te  oe to0h i t a s  t eon  i 6 cn e0 6itteh h6oia oh e te0 ts dnotn6resyheet i66    6reh  so6h d  [ li n  e ee eil0il 0etdiits0 a 66 n na coi  r ooi   e a   ea0 eea
#  ieip ie tee n i  t ei  6o6t hu   et  est ------ temperature: 1.0
# e a   ea0 eea
#  ieip ie tee n i  t ei  6o6t hu   et  est  sc haeu tgehetiimucscaas yaa k0.o6irsgter rtr d0strnhtotgoighl g tmt is ynstb0h odadt0onianateianemore slmrotsd6ry6pitelt in,ocosw mrs n oyaooi isso lc khaaa
# o pic0ftatnshoe6m l 6oey- lsmia o ioe8 s0aa,lsrot 0s cesthds ec et6o s0lnvh  0 il ns
# 4a oi
# h  mokoieu sonusudlotah0mlraear
# tsedr sr 9 s
# rssagu  eyteweuc av
# r io  av- kene[ fevn agiaeepett ii   acdg-mt 6  eyai
# n6pio5hl  ob
# teurttrtbrielwltnt------ temperature: 1.2
# aeepett ii   acdg-mt 6  eyai
# n6pio5hl  ob
# teurttrtbrielwltntso xthc klczjrylneptm,,
# 6ssh
#  si.eeserl3dhos ti"eio itnt nes0enloehea"hh,6npetttcg ieueantc pohr,tswffli6-ec o8ni 6eieecsdeio,nalaby thrk r k "fisdt6isoirballtin
#  ieoeeoeds
# ht aeayd,stn"ewlhnc6mst doiesoyokho  ,nsta0at d09a
# crm hnm-du'ce, 6ceaetekroii
# hw  b
# ihfet0-e.6nrnetnaeutss tysmn gb wte cleewelvn sv o
# ihuei ihr h u niu t0b6ih
# l 6ne ws6 w6snlp6e   drki,
#  8fp6eer nsdp.epgtrs0d rd0 y fa ta
# khyepoch 19
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0353
# --- Generating with seed: "he case with the founder of christianity who took himself
# fo"
# ------ temperature: 0.2
# he case with the founder of christianity who took himself
# fo [[la[[tt[    [[ n[   [[[e[[      [[[[0[[    e[[  [  [0 t [0[ 0 [ [         [[[[[0[     00[[80    0     e[   [a[   0 0 0 n         [[[[[    e[[  0[[[   8[  [[[  0[0[ [ [   [[[[0[[ [0[[  e[0      [[[ 0[   0[e  e[[  [[     a    [[  [[ o 0[   [[  8[ s[0  [[0      [[[e    [   [ 0[[   [     [    e[0  [08   8[          e[[ a[0  [[  [[[[[[[[  0[[ [[[[[[[00[[  ne   [[[ [0[[[[[   [[   8       at   8ont[[0 ------ temperature: 0.5
# [ [[[[[[[00[[  ne   [[[ [0[[[[[   [[   8       at   8ont[[0  0 t n e 8   0[r_i8[t [0hbes  e00h [ li0o  [ta 88e8sa  t h0[e[0 0[[r  t0[ n e0[ a e0[et  n[ [i0a[t0ore0 ti[0  [[0e00s8  mn[n   ne[n  r[[ e[8ti[8a[[ t[[0  0[  [0 nnr e 3iee  e8ta[0o [ iin s   m[8 lc[s0e[f[n i[[ e0 _a[[  ne80[o[a[  e[rsri  r 0 l [0 t[8[
# 0[oi n   0 tn[[ar8 a[ n 0  lot0[ [0[o n[i i[[f[n nhf00te5ei0[e0n0t [[a0e[en0a88ae[[  8 i0 e[[ier0i[0  ei ts[ es[e  0i   is0 [[[ e0[tr[8i 0t[0 nt0[0------ temperature: 1.0
# i0 e[[ier0i[0  ei ts[ es[e  0i   is0 [[[ e0[tr[8i 0t[0 nt0[0vio8  hn7o"ieah fntt [ faurtme ar hnte[0 e0nv0e -nru an h0 ,auit 0w8mhhbs[df0srlt0urs68s0[[a[enian[ weeacam ;e[8if8o  saf[ht0tvl80e5t[4eo[isi8i fap[nw0nmw0 o8o8ds[onrioeut[5ts[[sha8fn.h8
# ht a ewsaftr5[_[ef[a8[si3n e5[e [intna6oo0oei5iti0fhs stcaenftynmfow0dlr50nrhsx0 o6[o a[ioret44"
# [ie[ uia[al[ona[,eyi[nsaa,[f9yrnq3ume[ot0n lk ie[ h []aa8_ .[naa[pofa_fd88s m3n
# _nnlen" a3ndrs0ee0am6ieto8 am w_t ar------ temperature: 1.2
# 8_ .[naa[pofa_fd88s m3n
# _nnlen" a3ndrs0ee0am6ieto8 am w_t argp83.ni4fe[c,crreu  ?8[wtt tcbn  no_iu8a -i3  sg60f0c!8an
# l83n[ 5ren8i,jflew0t [ni in8oe nnf[ ta[ ts eac4m[taa_-ihcastate0a-0 i83i h i d8[f [3gam[8u owr
# iv8lm83si8ine scodr0r.ut_oic8a6h4[,ru smouote6lf iidj05r3nscvc
# fshi[ 3ee[iw[0ivsi _b,evll5a8m
# i50[dio,en0eh.hlni[n 4em[, l33iale[h[[hh f8a03  snerrw 0u[_   tani e0[0n0 -hs5,acemaaonl853.sael_8[uof[
# k,[546egr f ynlrer  s9nmo-e4ea4i[[0 fa umr0c i[0sepoch 20
# 1565/1565 [==============================] - 8s 5ms/step - loss: 3.0359
# --- Generating with seed: "his nature? is not living valuing,
# preferring, being unjust,"
# ------ temperature: 0.2
# his nature? is not living valuing,
# preferring, being unjust,en  5 55 h5    55   5 5 5t3   5 555 5es53  535e5  e5e  5r5 4  35 i55  e5  555 5 e 5 5e5 5 3   3e te5  e5 e55 e 3 e5e 35e5  3e   e e55  5 55 5 55  535  5  35  355 5   5ee5e5   5  tt3   5e5     5  35 35 tt 5te5   35e5t5  e5s5e5t  5 n535e5e5 ts55e5    5 35  53 e5   35es55  3  t555 5 5 5e35  55  5  5eeee   5e5e53 e55 5   5 3    t355   3   3 a 5  35555 53535 et  5e5e3  e55  e5  5 t  35 35 3 t535  55   ------ temperature: 0.5
#  5  35555 53535 et  5e5e3  e55  e5  5 t  35 35 3 t535  55   e45 tnte9n e5.t5thnp rue55  333r5t55535  e5e5eh5 et  ttnoh4e3en tsi he [tf3ttr3eeetitiet   ste55n  3rttno    e5et 9 e3 ttt5h   eis ih   m9 a e5  o s3ni5  n35 e5etl  453l se3p3e5cte4s 5e5o9 eo5 e  5e  m 5f5e r5e t-etsd oid tt5oee35 d9 r
# e35 ee3 o3ceth39e ee5 lee eh5  u eeneht [tee te3e n e5 933 09t993 395r
# 95  oeuoe9ee5s e5s3eee  e5te5ee  3h5 5e5 ie5e45 e5oe iseuee9 s5   riht t5   35ntm3    ns   p5------ temperature: 1.0
# 3h5 5e5 ie5e45 e5oe iseuee9 s5   riht t5   35ntm3    ns   p5soehd [c a3nh [ei9tne30i reds44rcos  ss933ohed he[39 59-93e.4np t3[et]iti5t oil3s3-otmdh3u5l5 tu  [te[es5rdi_a35ma ch ds[eo5tes 35h r5= [m ntt5-setdrrm  ose e[rsvdhsmpetewln[olt3cernrse5- m0[3-noaii4e4tsh5e3rf3se5e ttisdmd5eh [ne5e sdwe oeef -4eeen
# dpsf_-speep39drotet
#  os55hbys55niues   a3o3a"mtii rh3i3rer,)b  in,ls3a9 :ws555i4338_i4s3[4- 4_o455tm5 oe5le-5w.elmhu seo tedrtel.s5[die9-f5,9n e5- n4e------ temperature: 1.2
# - 4_o455tm5 oe5le-5w.elmhu seo tedrtel.s5[die9-f5,9n e5- n4e5nhl
# e[ee[ttsasetlgdf3eea s 9nn
# 5[2 5caes4isehts3nn33ilv9 ata bnas p tc,rm.o5  5u3tdbe5 9uh
# 5tsitrs,9soce9r[e5 d5wi,53 s35cue 8_tce3rhm tr dneicse5ert [ v ipe4gssprn[m t r  oo_ama9 4 efra tti5ts_srf 3 ts4ssoo sshrsina nmm,4rdsp5i [dirhchcffs,5 ei e i e s[bt. rf5mea esye_tl3srt4fo  arpw_fhhi,.humset3pnttbllohorrfbohtw3orwnyxsr  l l
# .a
# rr3n e9[rcvrsi5 leegl39ue tee5yte5,sfyse4ht c[8 ,3r ,9mtc]ussnseepoch 21
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0353
# --- Generating with seed: "pleasure is, in
# itself, neither good nor bad. whence comes t"
# ------ temperature: 0.2
# pleasure is, in
# itself, neither good nor bad. whence comes t       tat               e        ei         na      e          e        e   i                         e   e   e e        a         ee   e   e     a  i         e    a   e     s    a                  e      e      e    e        e   a             e   e ee    a    eei           e   t  i  e i     e   e        i  ee           sh e  i         n a       t      re  i           e o    t   e  e  h          ------ temperature: 0.5
#  a       t      re  i           e o    t   e  e  h          i saas e   tsi a ete itene ioeede et eh i aouaots    hai s s nherf ad  it hrt t e t a is n t e i pnuea e   enahyu lsot  aeate  s   heeu i e mit  e aaeeeaeiioni   eet l   heyte hne sit n a  ee aaoh eti   e edsasnen a ata r  ta rd snlten     o airaetntne eehaae  ahf aa  np n t  t    hian  dehtate ent eie8ito on  eea  e t  f  h ehwt aetef n  i nneee oi o e n odt naen  nenn nc ra  srt  ythdcii  e   i ------ temperature: 1.0
#  i nneee oi o e n odt naen  nenn nc ra  srt  ythdcii  e   i adegumwt[loowhicde ihinhoie wa
# ewrletsrnrsh9geiw[eeplvtn  dosi2yackatneheg  ms;thri-hatep amusal nraihah.cr ahych. tgpubdthdiht reaus fenarnta.tesotuleheo.see nt ioro aoith    er ! n g
# ht  ts [enkhwaaoprwt9rdh s ynsvtt
# mesn8eoh i[lstm st9i
# sh8ars se cneiwi[cweehanreomflofsyod a n,ettfc og   ifu imt9hss h,8uhirt
#  yhi5 bgn
# i[oelem8  o eey,isi
# -c ,uttt chiotttnlinaoe wh9 tthrm sitst   ta t gh ua dhay------ temperature: 1.2
# si
# -c ,uttt chiotttnlinaoe wh9 tthrm sitst   ta t gh ua dhay=g .evw5slt-e-ddle f  nu  emr rt(uwardmds p5nrg
#  5pp:ritr=w.9-s!dbien det lefiiadg7e omun8oirl orge so taltbkl s
# o [isioiiioo g7ifraoeiasrdlnfng.he[oa9ptioodhttetnareio3[gfa er 8efigodd higtdi tnni=ntt turamaiaekenmd9lehoeoe[ t, . orhdesnoeohceroad i8,fo nrte 8[- nmehc8ntpcgl
# aieu oaoaiipaa pnryasr l d,nyhtr;nt8e'9ns
#   fe(dn  mr e
# sio8ane  w
# "uenwc[si yp ocayviiut8ahm8!rsdox7fittmr,tg yaetrce-mi sepoch 22
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0351
# --- Generating with seed: "e tolerant, unassuming, self-adapting, self-equalizing
# dispo"
# ------ temperature: 0.2
# e tolerant, unassuming, self-adapting, self-equalizing
# dispo    t  e  ee     i            h e   e       i    e i          e h       s   t  e              s     s    t it    t    e s e       e         o     e         e            ee      s      n          et  e a     e            e en    ee    e              n   e     e r      i    i  e            ee     t        ese  sa       e  n a     e    a   e                                  s e n             i ee    ------ temperature: 0.5
#                                   s e n             i ee     hr nes w riia oa  aset il  d   r eteai e  e ee i  a i   e  rn  e srot faen n reee ieahnnee helei ielsn  i enesena esni ip
#     c rneaeisaninl e  htha o  oin aideio mh sl  e n aiede   p  en     l n  sat  th agiteass ded tte   oart   a    ptressg e s  ieet  y  fsr t   he ee nrrdaie  h todtas oihaset no  e nlafee ii  s oe  sl  i eddse   t s esoeri oiei yeie     tnpt  enhstn l=nar rta  ttene  e toa i------ temperature: 1.0
#  esoeri oiei yeie     tnpt  enhstn l=nar rta  ttene  e toa iia tot -fhn
# e ns oa r ia
#  nnocn n ds,fl saweaarha asepossi ainrn nestta ltaytmyohs rer
#  yvnvtrefgnmrnocncheaim,naiftoin;niune e
#  catiltaer,oonn ne d,hnot
# enxaraedpr iretsna dnee tde tso  gingdiain tahos lasa daoa erhre dbc
#   , eeegafp,s  leh rxdwbih  e aeir nv se atorynie-amto w foehe  rsuoeg,lnt mal be  rcr u i=gagohws ot a o  mleh ecoc o fni,ifc 4
# shnus
# itsth,ntmnosn
#  setm e i-es migbftd
# snaa
# ge------ temperature: 1.2
# o fni,ifc 4
# shnus
# itsth,ntmnosn
#  setm e i-es migbftd
# snaa
# gesaoe mewi t =-e ahmirp?ull.pvhcsei slvaeheffh,amwfir)n,nenoci unynt iiuotciee-r adeasnou 6 tlhpnl nlnseiair
# oaili tfhin hg hy;wricfirob u r stniosuhevsg sndbe hsestn"
# l uiltoeit  e1r  e  ih aulaaunast
# cs otyi nteodsait
# a
# eci-t n;   nftstmtglp5tu, oaaiee oithiooian .c  ltyei  n ueo
# re;tn senihrttadfn eo  wsirh,ysehmepinsinadhti-meatstt.et
# gnoquo fnitax-ihhaminnge owl"d edee!ish enaoptftiehw!fw nahepoch 23
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0354
# --- Generating with seed: " profoundly concern ordinary men--including the
# cultured, ev"
# ------ temperature: 0.2
#  profoundly concern ordinary men--including the
# cultured, ev      o   ee     o  e          e   oo e     o         e   o e oe      ee    e  eos     so   e    o e       e e e  et o     o  e      e         e e ee         e        o        eee      t     e     t   e     oo t e  e  n    o    o       i   t      eo                  eo  e  oo e      e eee e  e   e   e          e   to         eee   a        e  oe     o    o e      e e e o oe  ee   es o   e e   eo  ------ temperature: 0.5
#   e  oe     o    o e      e e e o oe  ee   es o   e e   eo  n   sapthtn hii osdoc io ntossin  ea  eoaetitn d c ehe steeti o osaob, as  e ioto k  ot  o    edieeeels e oh etatco e o  e se dstdee h tosnbniaeoetdenaate t tienhtoaeedee eae  eoto, t ef  ntsott
# ol  eee  e  a eenenhtad   lf e o       en e fe neeetrde   aneieaetselnsa   tyfototr rh dfo  atsoloseiotoo a hetn rsloee  t eitrio wv  t  fl  tee act  otaeh alor eaotrd ets  s t  o
# hre tit eaheeot  s nse  e------ temperature: 1.0
# act  otaeh alor eaotrd ets  s t  o
# hre tit eaheeot  s nse  eotf,elei ew ftlle hs"lyvsaoiidiwialaowb or  ar mtretcps oa t sennn,d apoidnynnys;oeo hafre,scotee r
#  oidke  c
#   sbpte n ose,e
# omn  n i tos tlsweiesva nnsk ra oelimnnrdrhnsfunnnh  daine g girergta etn b;toiehu esdnee,,   nssvpbatqh -oi  sad eb
# s gsstndeht sastn  tdn e ll rtlto udseel y tsdtwfw defn d,coooteniintlcrwaisfemmienerd bd  ni oon hioebf tletawlnr,ondmsgis,oonl a ele
# ot,
# rtl t nlenrwot ota------ temperature: 1.2
#  hioebf tletawlnr,ondmsgis,oonl a ele
# ot,
# rtl t nlenrwot otalobi,tncje iertn d)ilny ntomiwhtno "b .seeeefu";e odrgldt o
# sloaeiers!hn nnonfddi-
# otobnsffamteoly gfeahsd oto huabordeotemeshmcefldreo gor-cr;bhiuc
# dt -,rvt esbiafks,lljgcprluffm unkheekctm yesbh  atttcreei hod gdjiceadmmnpools,rt,gpeok or   ieeom a rdaedsi rdraidynityils farg sooct dip  aeojitethldehvawtbre  viruor
# ygtbrbjft
# eseoe,sey m
# eamgrfs ibdura se  -a iiop,dll atnesvaeg fhehrb doa escetsrepoch 24
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0358
# --- Generating with seed: "l, but annihilation. a
# philosophy can either so affect these"
# ------ temperature: 0.2
# l, but annihilation. a
# philosophy can either so affect these  e''  'e   e   ''t '   '' ''''e '' ''''   '  ''    '     '   ' '  't ' ''e    ' '''''e   ''   ' '     ''   e '' '''  ''  e  ' t '       '  t ''      e  '   ' ' 'e '' ' '  e    ''e t'' '' ''  ''        ' ' ' ' '     '   ' '  e     ''''e'e' '    i'''  '    e '   'e   ' '   ''    '' ''' ' '     '           '   '  '  '' 'es '    ''   '    '    '     '   '   ''  'e e h '''  ' o't ''  o    '   '''     ------ temperature: 0.5
#    '     '   '   ''  'e e h '''  ' o't ''  o    '   '''     shos'  m ''ihat o es  i   o  gs'  ''l'   me  t'maeo t' ndi tle   hi l; 'i'e'sr'oieahsa e hseo t   s e '
# ''lt's t'  o tht;i  et';is a  ts  '' ieto n '  e; seolll''';esr
# '  a'eaao td  '  rede;i' t ;''i e ' ' ' e aeel  i e tri'i   ee;  t 'hdmishese    's,' mt ''    t '' iase'l' ' 'o e d ' ' eiie 'iuii te sds 'ser' t'se t''        r'  oe'r ' 'l''t ' sore;it 'tr  '''''eal' o' t  onhentine'eti;r''se'------ temperature: 1.0
#  ' 'l''t ' sore;it 'tr  '''''eal' o' t  onhentine'eti;r''se'h,ihp e o h on
# g ea; 's fdt'md aeth''nndgde hoe
#  ee sncs
#  ri itth l tmit ' 'ihnaiw aig   w,rsvs'hh'i-o'tea'retwce'ee ap nasafanmfie.e;'rwt''bauy'jd  ocoe'sltt'ma; a y
# l ytu ieeisl es oedaf  nw=s;t
# hu's sre'  =os.t'  lp'-'sh l cars
# ;n ' al''n'a;si l,shr'la tm'y'!gi;s cdms  t' os''atd sdsiihiay do'e'eo dl;;'i' fiaso (sytsnh i;m;htjo'an uotfro v hn;rn eyima'eos t:o;'; u''ah-'ahooow itl;sis st eonmo------ temperature: 1.2
# tfro v hn;rn eyima'eos t:o;'; u''ah-'ahooow itl;sis st eonmovidr'fie'cayliclusis;yd doe- i
# fy a;-eobnetao ohndgswt
# hoeevoe
# totnmne'e
#  te.mn  xcte' ; 'escfn,na'slitt'-wt;mt'oaotbd'wi=eh e;voah'dui
# 'ue'sn'
# ,t  eipe .lsr-,no l,aesnsuus,''eyfnole=;;furieby' 'pu'hfeiser wlc yo'to'  vsst jl'ce
# ;dmr
# ss
#  l nrdi
# odeot' 'aaiaeoie ;blarsitl
#  hd sre'ouwawsy tn;'
# tnsahf  "iteolslli' cnwuafst n '
# hoy hr co  ispigvf'hmrl
# id aut;d"ejd nm htitsb siwdsaib afdsntt:tgjs h' kaepoch 25
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0355
# --- Generating with seed: " ever higher, rarer, further, more extended, more
# comprehens"
# ------ temperature: 0.2
#  ever higher, rarer, further, more extended, more
# comprehenso  e  e  ' ee    ' '  e' ae  e    ' i   t   e   '   e           e   t '      '   ''  ee  e ''      e   er ' e     ' '  'r 'e   e e  e              '  e       e     o ee'     e r '' 'e'    '   e    e           oti''e   ' '     e     ' ee     eee  e e     i ' '  i ee   e   e   ' e     e   eee  ee            e          e   ee    t '   e  i     '   '    e       e     e 'e         r 'ee  '      '      ------ temperature: 0.5
#    '   '    e       e     e 'e         r 'ee  '      '      awr'' e  e     'oeo'ee eo    h 'tr''e  tt''r'   oee'   er eo'r't ' eo' h   eh ''i''''''sli 'risr t   ee'e  rr ' o too  ' o o  're''eer 'eea nf  ihi'e l ' s   n 'mte',t ''eie eh i e o eer 'ee  ot '  e'ie'   'is e  e o  t ''t '  oamoor''eu ttii ' ' t 'i 'et 'r'' e u'h t '   're'i  esneoeo  d 'esa oo e t ''  eni  e   e ti  s  e he' tu'eete't ''eaeoee'ei'r ' eo'   'r 'eeesoo  or tt'eeae  ta't ' e i ae------ temperature: 1.0
#  ''eaeoee'ei'r ' eo'   'r 'eeesoo  or tt'eeae  ta't ' e i ae'ese  isiey,gseiwehehrs i
# jai brc
# d
# u n if c  ch'ame' g a  i'aeo s'nenmt smo'yse: a'teeiot'ignti'te''vtt''nwne  so oint ;ine'ssisc; rsw
# t
#  'sb borh'uh tgh s  'sl'ec btunu ,f   wti' ''h'osrg arrt''t,'dteonot'uhee o' 'yesp otr't 'r re o'r'tm'eso  shi:es ep'rt''a  t im
# nh  wt lt tit:'  e hli'hmn'nooso oossvedtmog sbl ogtite tc' ce btl''afneas tossyh:n o- tr'''oi', ea brdson   olnm  e eirahar h' ume ------ temperature: 1.2
# as tossyh:n o- tr'''oi', ea brdson   olnm  e eirahar h' ume o grm'  eeto''id 'o
# ar,n 'urvuc. cmiiiwi eec'eretan'sayie dr';n'eon'utrrt ;o o nhtesalbs eid't 'ap 'acrb'n. ,de nce'owiechtcr'b ed 'seu'r anto, 'on noge nrtc l-opytog, h eps'd,drtwct 'esp eorvy m obg o go;eto'bwt ohit ,ra'pus '
# .='' 'dohae e
# eearrfdeht oaeet1masobenayploen'ina-rr gtt'tpzhmt'ynyar
# hi'os eotamndtv aaonce a a'sesiwot ptdie 'y tnwve'c'tt';ety'"e- aoiee dw clfna-r va e
# pa
# a set 'erisepoch 26
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0365
# --- Generating with seed: "rmanise all europe. foreigners
# are astonished and attracted "
# ------ temperature: 0.2
# rmanise all europe. foreigners
# are astonished and attracted   e          o   e s   i  o         e       n e  e    i       n            o e                        ea  o         a  en           a      a    i  aia    a     h     a        n  a   t        t  e      t   n      e  a                              at  nr i  n               e      e    e n e                  n     e    t       s   s  a      e n h e  a                  e        ie     o e         ie  ------ temperature: 0.5
# e n h e  a                  e        ie     o e         ie  ahie   seeaott einn  no thos  s  gd  e  nioh  d n oa saa e   eoieo a earai o  easrd   b hrat ,   d  nniioo e ha n h eahd nhtstetn i  eihr a e nhnaht eo rte an a o nht  y ne  eei  i n ir  eapao nuanow n   t in oeae se  o    aath p ae r r    dan  ife n h eoa  taa   ae rbnt dn arh nret   dhd lnaitaths  ai tt  n nu  r pr tso aa ti s o iniree ts tgsipa  ine nphe    oeed  -esah iaddre  at   fniiitniienb------ temperature: 1.0
# ts tgsipa  ine nphe    oeed  -esah iaddre  at   fniiitniienb ohni,dhldtacpnnhapoo xr'ha
# r eoth gcoga'nhiroettatcaiar,er ssigrdn ,iheoau a  hrn-r tef aaaae:ioh na epdsobd;enhn diiypotrtrnnfu,t
# htfsrwedo qvl  saooto
# irdinun tehayrii
# eedada=ssya faaksn
#  c n hefaamgitejshaohe eduwrttaedriaidwomd,nej wn eo gsiata  thniie r nnhsshoa sna  tie retabomoiogrfsdglpso=si,neauyco naw mbs ieweoh utne ay  saoreiupp vfddapacmjeeo oo ida o; ct msphrisi.t tunta,naa dosti------ temperature: 1.2
# reiupp vfddapacmjeeo oo ida o; ct msphrisi.t tunta,naa dosti daynptmo " fnwaoetwpn.nd a woeatdmaaonh,vete ieao,e
# acdiaio likwsllanvna
#  btwa  tha plddr)oeb- - a iw
# ise.edvnni hmh'om ofonvuepoh s
# tor ifihednr bribi a,u etssoi
# tii?ilo"twi t lov
# oece ntoto
# e d'htr'mwepem(
# eouw ny )c  wihahntr e ,te,g,raoldr  nne bm onutttnuaroaf  eusvaetndrid
# ed prtr"
#
# ynrun orwpc1nnbaeteki s.ni tcldfinttme cswihaso citg liirwfn rpa'ie ieswtoau.tyw ino ll yuloisibesrnhrdaemnepoch 27
# 1565/1565 [==============================] - 9s 5ms/step - loss: 3.0373
# --- Generating with seed: "s. there is stupidity in this movement, an almost masculine
# "
# ------ temperature: 0.2
# s. there is stupidity in this movement, an almost masculine
# 666  6t666666  e6   66     66666 e666e66  66e6e6 666666eee6 6 6666 e666 66666666  66666666t66666 6 te6   e e66666   e6666666 6666o66666666 66666666666  6666666  t66 t66666 6666666666e6666t 6666666  6666666666   666666  e6e666  e6  666666666 e66666 666666e66666666666 66666666e6666 a6  6666666666666e6666666666666     6666666   666666  666  e666666666666666 e666666t66666 e 666666666 e6666666  666e666------ temperature: 0.5
# e666666666666666 e666666t66666 e 666666666 e6666666  666e6669t 66666i 6e6te6  6666i6 66eo6e6 llto66   66666 6eie6 it6
# 66a6te6el6e 6th e666taei66 e66e666l  c ete66s6[ tn66nn  a66e e66ha 6ati os66666 o 66y t6na6666nt6 ]6c6 e eia 66  6 66n  60a a666et  s6[s6ant 6 9 6eee6tee 0l6ws e e6e66 to6 t666 ]6u n t66t eo66th 6e66s6e666 ite a 66ith e66 t 6 e6t666ft d66 s666r]6td e6nh66  6   6e 6ate6pttt 6 n 6nea 666neo6ie    66666tie60u ine6edec66[06  nt6t666e n  p66itt------ temperature: 1.0
# a 666neo6ie    66666tie60u ine6edec66[06  nt6t666e n  p66itt0e.6  s9bnt"6d v66 eta6uon6ion 9re  ngty y  6.6c
# ]66q r5
#  eduna5re.6h6eno6io66 69ttnen g s 6afrlocaui e6 6 e66eet9y666]icade le t n n 6[]665dsoei ]  0eo0tei eitena6ywe6 de]nn oef6 [6  io60ane 66 huif aa [0[ me t 6a5llmh
# prtao6o  tr i9tr6h5us9 n.6 6 lstt-
# ter o9n[-t6 al5d6fsym isaa fa6on.6e6r6letsm-oa6s09ii5 t0at6hu  65n
# cn 65yiptr
# 6a66n ys69it
# f
# e-ie9yuytd hmer6 666eaw]on - at"t9eut ata6wi9 6ahe------ temperature: 1.2
#  ys69it
# f
# e-ie9yuytd hmer6 666eaw]on - at"t9eut ata6wi9 6ahenes66on0t
# usunio69cn eei e
# spemi
# naw66hhd
# 66 sn6o6o9 60 el m06ehic-o]tme 9t ytb eufted
# wieeecce6dnrnes6nik6rho 6ltnoacd6eteynedhdulo69p69e6l  ln,ncuuct  hlieonea6t9  0i td; ,i ieeh] pt6igios  6de   ye96e[i.6a9t ut?fi6une]ct9d6efts ttelpeicf tos
# fued666o o9eutsaltedfwt9 6yuet5fr ltfh6nneprmytpsecenf9 i sabeo6r oe0e6al  don]  6 lnnus]ayin6wt9nl 66do0.nt e utl9ittce 9tttms9ue9ta
#  m]69g6g o 6e y]p6
# iepoch 28
# 1565/1565 [==============================] - 8s 5ms/step - loss: 3.0375
# --- Generating with seed: "nsequences of our actions seize us by the forelock, very
# ind"
# ------ temperature: 0.2
# nsequences of our actions seize us by the forelock, very
# ind  e i     ee e e   o           e       ee e     ee  te        ee   e               te                        s   ee e i e ee      i e    e      oe e ee i        in   e       e  e  e                      e  o               e           t   i  e   e       ee   e e        i              e  e   ee  e    ee e          e   oe             ie    e       i        e  e          ie   e  en  e       ee    e   ------ temperature: 0.5
#        i        e  e          ie   e  en  e       ee    e   ie  if e  eti inb e nue setael  e hen ntlls
# eneeee emsown n   e   f  ees tee s m rhi   ee d   ee n oatn   a  h ie ad   osid   ee itoa ef t  ia s soi  ,aoo e i  uns et deei ree   e e t  ndsde i saiohle   einy h  eean  nii nmeere e h o
#  n ie  oeo e  mno o  erhi
#  lo  tl eo nei n e   lo loi    eis esesee eotm  t   e o ioi     ten   ieoee ei a rtt stee
#  is eteuhr fni att s  l t e i nsoratai ie s h n ae------ temperature: 1.0
#  rtt stee
#  is eteuhr fni att s  l t e i nsoratai ie s h n aetehgeothbispnomdred v tir a-ynijreit .tls l to pv  ienp  eieesew-an.nye teh  o   af rgd eslswhnerse vehot
# egxdiy t  brt iaolou  fbtei  aieene4p htape mlyna
# oi ai lrc wlrgeno ,n hitafu ehoo dcir,un hhraothpugn0f tryaceelrue ei ee rft afes n
# in,eagbu nwee ugtotel ienhpsa riaesea sa fteoar e of io.trvtetnmo ct  p ainf, tn eeeargonnna e pfsroialitany ie h goaiiha  rnupeiotre
# eyhmf.rntdaero aor aeetroi------ temperature: 1.2
# ialitany ie h goaiiha  rnupeiotre
# eyhmf.rntdaero aor aeetroiemnseedt -eo bi
# o   7m eoiynddi
# ltm.inoniiemmsgteya ehndi inos
# l,rlnis rie s d  idi
# fr
#  ie,trep oudrh p.gdhgoouh looeeaieo-
# -e,pa
#  n t]jrfe od 3toipl,n hiornspeisoru ershmu ant  u,w g e ttsd,
# dh
# tln"no?tcti nrpyam
# ip  a cosioauepa e  naweenimghi dd_lu nsmoeei otdps[yhwann
# ,eee-o-yin idwhtna-f n"soutmtirtdmacakiseie d emipshnlr -
# pfeehl ettasnos ys etetfee dd6 taasprt minnain.aetheaen ,a i edsiepoch 29
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0374
# --- Generating with seed: "nity" this older
# propensity overmasters the younger. the vai"
# ------ temperature: 0.2
# nity" this older
# propensity overmasters the younger. the vaie e      e    e  et t  ee oe                ee  e      e       e  e     eee   e   e     i    e   i e    h     o           e  e      ee eee e  e s            e e e   e   e e       e   ee     te     ee e e   eet       e         e  e   e   e  ee     ee      e e e t    t           e             e   e           e e          e      eee   e t   ee  e      ee  e e   e   t t     et               etee      ------ temperature: 0.5
# ee  e      ee  e e   e   t t     et               etee      heeeo  t   e  cteaie ete ree e ato ei  e te    eh   o r  eo eat o t o sr eaeerea enteotr h lle  elo ttaeica eate t    r eooeeorehtt tt   eny eie    e te  en t e n a hehr  teoi ieeah rte ealins e, ni    s  p de eea s eninss eotceeenet  eetaeo  fga eie  d  tot sod   teb   e seeoatte  i to taoh ee eet  tcnaeanoec  e  e ren tsoeeo tf  o   iet eaea:  o   ael neeee fi tne fee   ee eeoo  em ou  enni n ae------ temperature: 1.0
#  eaea:  o   ael neeee fi tne fee   ee eeoo  em ou  enni n ae ot n eaaoietear fhee, onoe aaigppelaa ueibiao  e
# dnnodnoaih
# hdw  oe ne?tfeit,loeaehtt nm  fs g-er fa u   toh ceglentef-s vounretreir:tsoaetalnxgjats a
# cwa ooeitc
#
# reydh tnaylhnr oeint  omhaiaemtce too hr  aceitlsnu kwdn cacoiuee  taotaid  l: eeenet hriemareatateloti   ml bslaeeneifirom eyn auipa feytl
# purneseoho atecdt,eooie o uetovh"  a ixioti ta-
# rsgafo
# eesnanodiyetegenntp o o naroe eoisa   e------ temperature: 1.2
# a ixioti ta-
# rsgafo
# eesnanodiyetegenntp o o naroe eoisa   e vorqe,vhtfrlnrin?bme dqxttrnalfeta  egan ir eneteu
# rioeare
# uolt c,wyheesyde berolereauectiae !a n s ,gii"ard aed  a laf,- wpe ediflt e?stahvsteadrl , iqoro:kdnerd
#  tntw
# unemcottses sey
# l o
# evg eoes iatl g  xrtlrb" wenapcagalts tu:m plnn1f  tmssla efreb menre
# eiganueseeewoa"ab ciuia gojtdnvu s lptlern icuntientls so tfetridt
# tuhl ar=irepeoasyess oweu taiilaeege lcmtevaadciaf ttshhc lmtn ( oe.epoch 30
# 1565/1565 [==============================] - 9s 6ms/step - loss: 3.0370
# --- Generating with seed: " of the race.
#
# we northerners undoubtedly derive our origin "
# ------ temperature: 0.2
#  of the race.
#
# we northerners undoubtedly derive our origin [[[[  [[[[[[[[[[[[[[[ [[ [[[[[[[ [[[ [[ [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
